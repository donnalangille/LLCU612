# %% [markdown]
# ## Mini-Assignment 1

# %% [markdown]
# This assignment is to generate a list of current headlines from CBC and FoxNews.
#
# First, I will request the source code from FoxNews.

# %%
import urllib.request
from bs4 import BeautifulSoup

foxSource = urllib.request.urlopen('https://www.foxnews.com').read()

# %% [markdown]
# I will generate headlines from FoxNews using BeautifulSoup.

# %%
foxSoup = BeautifulSoup(foxSource, 'lxml')
foxArticles = foxSoup.find_all('article')
for foxArticle in foxArticles:
    foxHeader = foxArticle.find("h2")
    if foxHeader:
        foxAnchor = foxHeader.find("a")
        print(foxAnchor.string)
# Out:
# The new socialism: Calls growing on the left for free college for all
# Did the president cave to Nancy Pelosi?
# Pet hedgehogs associated with salmonella outbreak
# Could there be a peaceful power change in Venezuela?
# White House counting on moderate Dems
# Dem hopefuls begin early rollouts for 2020
# CEO on impact of shutdown on breweries
# Kildee on chances government will shut down again
# State says it found 95,000 non-citizens on voter rolls and 58,000 of them have voted
# FRANK MINITER: Second Amendment supporters rejoice over SCOTUS news
# Pelosi: Stone indictment shows ‘attempt' by Trump campaign to 'influence' 2016
# Pair of Russian bombers buzz North American coastline
# Freshman Democrat asked for leniency for men accused of trying to join ISIS
# The new socialism: Calls growing on the left for free college for all
# Did the president cave to Nancy Pelosi?
# Pet hedgehogs associated with salmonella outbreak
# Could there be a peaceful power change in Venezuela?
# ...

# %% [markdown]
# Now I'm going to try generating the headlines from CBC.

# %%
import urllib.request
response = urllib.request.urlopen('https://www.cbc.ca')
html = response.read()
html
# Out:
# b'\n        <!DOCTYPE html>\n        <html lang="en">\n            <head>\n                <title data-react-helmet="true">CBC.ca - watch, listen, and discover with Canada&#x27;s Public Broadcaster</title>\n                <meta charset="utf-8" />\n                <meta name="viewport" content="width=device-width, initial-scale=1" />\n                <link rel="manifest" href="/a/manifest.json" />\n                <link rel="apple-touch-icon" href="/a/apple-touch-icon.png" />\n                <link rel="icon" type="image/x-icon" href="/a/favicon.ico" />\n                <link type="text/css" href="/a/styles/main.css" rel="stylesheet" />\n                <script type="text/javascript" src="//js-sec.indexww.com/ht/p/182851-247776411096411.js"></script>\n                <link data-react-helmet="true" rel="canonical" href="http://www.cbc.ca/"/>\n                \n                <meta data-react-helmet="true" property="og:site_name" content="CBC"/><meta data-react-helmet="true" property=
# ...

# %% [markdown]
# Next, parse the document using Beautiful Soup.

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(html, 'lxml')
soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <title data-react-helmet="true">CBC.ca - watch, listen, and discover with Canada's Public Broadcaster</title>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link href="/a/manifest.json" rel="manifest"/>
# <link href="/a/apple-touch-icon.png" rel="apple-touch-icon"/>
# <link href="/a/favicon.ico" rel="icon" type="image/x-icon"/>
# <link href="/a/styles/main.css" rel="stylesheet" type="text/css"/>
# <script src="//js-sec.indexww.com/ht/p/182851-247776411096411.js" type="text/javascript"></script>
# <link data-react-helmet="true" href="http://www.cbc.ca/" rel="canonical"/>
# ...

# %%
for headline in soup.find_all("h3", class_="headline"):
    print(headline.text)
# Out:
# Stalkers: 'If I stay at my current address, I'm going to end up dead'
# How Keith Gretzky ended up as the Oilers' interim GM
# This 7-year-old Newfoundland girl likes purses so much she started her own company
# Why ex-NHLer Clint Malarchuk wrote about his struggles with addiction & mental illness
# 9 reasons the 92-93 NHL season was just crazy
# The best Instagram accounts devoted to '90s style icons & dreamboats
# Wind chill myths: The cold truth behind a go-to measure
# John McCallum fired as ambassador to China amid diplomatic crisis
# Huawei arrest: What's happening between Canada and China?
# Canada's new food guide might be free of industry influence, but the great food fight isn't over yet
# What we know and don't know about the alleged Kingston terrorist plot
# Daughter, 18, charged with 2nd-degree murder after woman reported missing in Ottawa
# Lincoln Fields owner moves to demolish aging mall
# Man embarks on 19-hour skate to support Alzheimer's programs
# ...
